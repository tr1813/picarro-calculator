# %%
cd ..
# Out:
# C:\Users\csav6865\Documents\GitHub\picarro-calculator

# %%
import Picarro as pica
import PicarroDatabase as pdb
import pickle
import pandas as pd

# %%
conn = pdb.CreateConnection(r"J:\c715\Picarro\Results\Database\data.db")

# %%
df1 = pd.read_sql_query("select * from runs r, runlookup rlk where (r.'Identifier 2' like '%TR%' and r.'Identifier 1' like '%GNS%' and r.RUN_ID = rlk.RUN_ID);",conn)

# %%
df1
# Out:
#       key Identifier 1 Identifier 2    RUN_ID  position  d18O vsmow  \
# 0   10281        GNS-1           TR  20191006        26  -11.709281
# 1   10369       GNS-02           TR  20191010         6  -11.555868
# 2   10370       GNS-03           TR  20191010         7  -11.282312
# 3   10371       GNS-04           TR  20191010         8  -10.932605
# 4   10373       GNS-05           TR  20191010        10  -10.956193
# 5   10374       GNS-06           TR  20191010        11  -11.006156
# 6   10375       GNS-07           TR  20191010        12  -11.025120
# 7   10376       GNS-08           TR  20191010        13  -10.515545
# 8   10377       GNS-09           TR  20191010        14  -10.065915
# 9   10378       GNS-10           TR  20191010        15  -10.468065
# 10  10379       GNS-11           TR  20191010        16  -10.405369
# 11  10380       GNS-12           TR  20191010        17  -10.343425
# 12  10382       GNS-13           TR  20191010        19  -10.849865
# ...
